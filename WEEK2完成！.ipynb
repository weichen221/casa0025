# %% [markdown]
# <a href="https://colab.research.google.com/github/weichen221/casa0025/blob/main/WEEK2%E5%AE%8C%E6%88%90%EF%BC%81.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install duckdb duckdb-engine jupysql
import duckdb
import pandas as pd

# %load_ext sql
# %config SqlMagic.autopandas = True
# %config SqlMagic.feedback = False
# %config SqlMagic.displaycon = False
# Out:
# Requirement already satisfied: duckdb in /usr/local/lib/python3.12/dist-packages (1.3.2)
# Collecting duckdb-engine
#   Downloading duckdb_engine-0.17.0-py3-none-any.whl.metadata (8.4 kB)
# Collecting jupysql
#   Downloading jupysql-0.11.1-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.12/dist-packages (from duckdb-engine) (26.0)
# Requirement already satisfied: sqlalchemy>=1.3.22 in /usr/local/lib/python3.12/dist-packages (from duckdb-engine) (2.0.46)
# Requirement already satisfied: prettytable>=3.12.0 in /usr/local/lib/python3.12/dist-packages (from jupysql) (3.17.0)
# Requirement already satisfied: sqlparse in /usr/local/lib/python3.12/dist-packages (from jupysql) (0.5.5)
# Requirement already satisfied: ipython-genutils>=0.1.0 in /usr/local/lib/python3.12/dist-packages (from jupysql) (0.2.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from jupysql) (3.1.6)
# Requirement already satisfied: sqlglot>=11.3.7 in /usr/local/lib/python3.12/dist-packages (from jupysql) (25.20.2)
# Collecting jupysql-plugin>=0.4.2 (from jupysql)
#   Downloading jupysql_plugin-0.4.5-py3-none-any.whl.metadata (7.8 kB)
# Collecting ploomber-core>=0.2.7 (from jupysql)
#   Downloading ploomber_core-0.2.27-py3-none-any.whl.metadata (532 bytes)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from ploomber-core>=0.2.7->jupysql) (6.0.3)
# Collecting posthog>=3.0 (from ploomber-core>=0.2.7->jupysql)
#   Downloading posthog-7.8.3-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prettytable>=3.12.0->jupysql) (0.5.3)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.3.22->duckdb-engine) (3.3.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.3.22->duckdb-engine) (4.15.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->jupysql) (3.0.3)
# Requirement already satisfied: requests<3.0,>=2.7 in /usr/local/lib/python3.12/dist-packages (from posthog>=3.0->ploomber-core>=0.2.7->jupysql) (2.32.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from posthog>=3.0->ploomber-core>=0.2.7->jupysql) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.2 in /usr/local/lib/python3.12/dist-packages (from posthog>=3.0->ploomber-core>=0.2.7->jupysql) (2.9.0.post0)
# Collecting backoff>=1.10.0 (from posthog>=3.0->ploomber-core>=0.2.7->jupysql)
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: distro>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from posthog>=3.0->ploomber-core>=0.2.7->jupysql) (1.9.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0,>=2.7->posthog>=3.0->ploomber-core>=0.2.7->jupysql) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0,>=2.7->posthog>=3.0->ploomber-core>=0.2.7->jupysql) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0,>=2.7->posthog>=3.0->ploomber-core>=0.2.7->jupysql) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0,>=2.7->posthog>=3.0->ploomber-core>=0.2.7->jupysql) (2026.1.4)
# Downloading duckdb_engine-0.17.0-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.7/49.7 kB 4.9 MB/s eta 0:00:00
# Downloading jupysql-0.11.1-py3-none-any.whl (95 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.1/95.1 kB 7.8 MB/s eta 0:00:00
# Downloading jupysql_plugin-0.4.5-py3-none-any.whl (192 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 192.8/192.8 kB 19.1 MB/s eta 0:00:00
# Downloading ploomber_core-0.2.27-py3-none-any.whl (22 kB)
# Downloading posthog-7.8.3-py3-none-any.whl (192 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 192.5/192.5 kB 19.2 MB/s eta 0:00:00
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Installing collected packages: backoff, posthog, duckdb-engine, ploomber-core, jupysql-plugin, jupysql
# Successfully installed backoff-2.2.1 duckdb-engine-0.17.0 jupysql-0.11.1 jupysql-plugin-0.4.5 ploomber-core-0.2.27 posthog-7.8.3

# %%
# %sql duckdb:///:memory:

# %%
# %%sql
#
# INSTALL httpfs;
# LOAD httpfs;
# Out:
# Empty DataFrame
# Columns: [Success]
# Index: []

# %% [markdown]
# Q1:Create a database, then write a SQL query to create a table named nyc_subway_stations and load the data from the file nyc_subway_stations.tsv into it. Similarly, create a table named nyc_neighborhoods and load the data from the file nyc_neighborhoods.tsv into it.
#
# link1： https://storage.googleapis.com/qm2/CASA0025/nyc_subway_stations.tsv
# link2：https://storage.googleapis.com/qm2/CASA0025/nyc_neighborhoods.tsv

# %%
# %%sql
# CREATE OR REPLACE TABLE nyc_subway_stations AS
# SELECT *
# FROM read_csv_auto(
#   'https://storage.googleapis.com/qm2/CASA0025/nyc_subway_stations.tsv',
#   delim='\t',
#   header=true
# );
# Out:
# Empty DataFrame
# Columns: [Success]
# Index: []

# %%
# !curl -I https://storage.googleapis.com/qm2/CASA0025/nyc_subway_stations.tsv
# Out:
# HTTP/2 200
# content-type: application/octet-stream
# x-guploader-uploadid: AJRbA5W7FABMX_XGgPW4RgY0t5aE3rjRi3jjmKQo-rtXoNxKHe-oD3EC2j6GsVPizzJiuK8
# expires: Sun, 08 Feb 2026 14:02:40 GMT
# date: Sun, 08 Feb 2026 13:02:40 GMT
# cache-control: public, max-age=3600
# last-modified: Tue, 13 Jan 2026 11:11:11 GMT
# etag: "0729767540b5545b23d063eeb23818c0"
# x-goog-generation: 1768302671934932
# x-goog-metageneration: 1
# x-goog-stored-content-encoding: identity
# x-goog-stored-content-length: 61763
# x-goog-hash: crc32c=efzBPA==
# x-goog-hash: md5=Byl2dUC1VFsj0GPusjgYwA==
# x-goog-storage-class: STANDARD
# accept-ranges: bytes
# content-length: 61763
# server: UploadServer

# %%
#READ TABLE

# %%sql
SELECT * FROM nyc_subway_stations
LIMIT 5
# Out:
#    OBJECTID     ID          NAME         ALT_NAME         CROSS_ST  \
# 0         1  376.0  Cortlandt St             None        Church St
# 1         2    2.0     Rector St             None             None
# 2         3    1.0   South Ferry             None             None
# 3         4  125.0      138th St  Grand Concourse  Grand Concourse
# 4         5  126.0      149th St  Grand Concourse  Grand Concourse
#
#                                 LONG_NAME                             LABEL  \
# 0            Cortlandt St (R,W) Manhattan                Cortlandt St (R,W)
# 1                 Rector St (1) Manhattan                     Rector St (1)
# 2               South Ferry (1) Manhattan                   South Ferry (1)
# 3  138th St / Grand Concourse (4,5) Bronx  138th St / Grand Concourse (4,5)
# 4    149th St / Grand Concourse (4) Bronx    149th St / Grand Concourse (4)
#
#      BOROUGH NGHBHD ROUTES TRANSFERS   COLOR  EXPRESS  CLOSED
# 0  Manhattan   None    R,W       R,W  YELLOW     None    <NA>
# 1  Manhattan   None      1         1     RED     None    <NA>
# 2  Manhattan   None      1         1     RED     None    <NA>
# 3      Bronx   None    4,5       4,5   GREEN     None    <NA>
# 4      Bronx   None      4     2,4,5   GREEN  express    <NA>

# %% [markdown]
# 4.2 Question 2: Column Filtering
# Write a SQL query to display the ID, NAME, and BOROUGH of each subway station in the nyc_subway_stations dataset.

# %%
# %%sql
# SELECT ID,NAME,BOROUGH FROM nyc_subway_stations
# Out:
#         ID               NAME    BOROUGH
# 0    376.0       Cortlandt St  Manhattan
# 1      2.0          Rector St  Manhattan
# 2      1.0        South Ferry  Manhattan
# 3    125.0           138th St      Bronx
# 4    126.0           149th St      Bronx
# ..     ...                ...        ...
# 486  909.0     JFK Terminal 8     Queens
# 487  903.0     Federal Circle     Queens
# 488  902.0  Long Term Parking     Queens
# 489  901.0       Howard Beach     Queens
# 490  900.0            Jamaica     Queens
#
# [491 rows x 3 columns]

# %% [markdown]
# 4.3 Question 3: Row Filtering
# Write a SQL query to find all subway stations in the nyc_subway_stations dataset that are located in the borough of Manhattan.

# %%
# %%sql
# SELECT * FROM nyc_subway_stations
# WHERE BOROUGH = 'Manhattan'
# Out:
#      OBJECTID     ID                NAME     ALT_NAME          CROSS_ST  \
# 0           1  376.0        Cortlandt St         None         Church St
# 1           2    2.0           Rector St         None              None
# 2           3    1.0         South Ferry         None              None
# 3          25  296.0            W 4th St         None           6th Ave
# 4         242  121.0            103rd St         None     Lexington Ave
# ..        ...    ...                 ...          ...               ...
# 135       374   72.0             Wall St         None        William St
# 136       375  378.0        Whitehall St  South Ferry          Water St
# 137       383  491.0        Cortlandt St         None     West Broadway
# 138       480  492.0  World Trade Center  Chambers St         Church St
# 139       481   99.0            Times Sq      42nd St  7th Ave/Broadway
#
#                                           LONG_NAME  \
# 0                      Cortlandt St (R,W) Manhattan
# 1                           Rector St (1) Manhattan
# 2                         South Ferry (1) Manhattan
# 3                      W 4th St (B,D,F,V) Manhattan
# 4                            103rd St (6) Manhattan
# ..                                              ...
# 135                         Wall St (2,3) Manhattan
# 136      Whitehall St / South Ferry (R,W) Manhattan
# 137                      Cortlandt St (1) Manhattan
# 138  World Trade Center / Chambers St (E) Manhattan
# 139                      Times Sq (1,2,3) Manhattan
#
#                                     LABEL    BOROUGH NGHBHD   ROUTES  \
# 0                      Cortlandt St (R,W)  Manhattan   None      R,W
# 1                           Rector St (1)  Manhattan   None        1
# 2                         South Ferry (1)  Manhattan   None        1
# 3                      W 4th St (B,D,F,V)  Manhattan   None  B,D,F,V
# 4                            103rd St (6)  Manhattan   None        6
# ..                                    ...        ...    ...      ...
# 135                         Wall St (2,3)  Manhattan   None      2,3
# 136      Whitehall St / South Ferry (R,W)  Manhattan   None      R,W
# 137                      Cortlandt St (1)  Manhattan   None        1
# 138  World Trade Center / Chambers St (E)  Manhattan   None        E
# 139            Times Sq / 42nd St (1,2,3)  Manhattan   None    1,2,3
#
#                    TRANSFERS   COLOR  EXPRESS  CLOSED
# 0                        R,W  YELLOW     None    <NA>
# 1                          1     RED     None    <NA>
# 2                          1     RED     None    <NA>
# 3              A,B,C,D,E,F,V  ORANGE  express    <NA>
# 4                          6   GREEN     None    <NA>
# ..                       ...     ...      ...     ...
# 135                      2,3     RED  express    <NA>
# 136                      R,W  YELLOW     None    <NA>
# 137                        1  CLOSED     None    True
# 138                A,C,E,2,3    BLUE     None    <NA>
# 139  A,C,E,N,Q,R,S,W,1,2,3,7     RED  express    <NA>
#
# [140 rows x 14 columns]

# %% [markdown]
# 4.4 Question 4: Sorting Results
# Write a SQL query to list the subway stations in the nyc_subway_stations dataset in alphabetical order by their names.

# %%
# %%sql
# SELECT * FROM nyc_subway_stations
#
# ORDER BY NAME ASC
# Out:
#      OBJECTID     ID                NAME      ALT_NAME           CROSS_ST  \
# 0         244   22.0            103rd St          None           Broadway
# 1         243  192.0            103rd St          None  Central Park West
# 2         242  121.0            103rd St          None      Lexington Ave
# 3         376  174.0            103rd St  Corona Plaza      Roosevelt Ave
# 4         377  239.0            104th St          None        Liberty Ave
# ..        ...    ...                 ...           ...                ...
# 486        72  138.0            Woodlawn          None         Jerome Ave
# 487       480  492.0  World Trade Center   Chambers St          Church St
# 488       240  334.0         Wyckoff Ave    Myrtle Ave         Myrtle Ave
# 489       241  303.0             York St          None             Jay St
# 490        73  152.0          Zerega Ave          None    Westchester Ave
#
#                                           LONG_NAME  \
# 0                            103rd St (1) Manhattan
# 1                        103rd St (A,B,C) Manhattan
# 2                            103rd St (6) Manhattan
# 3                103rd St / Corona Plaza (7) Queens
# 4                               104th St (A) Queens
# ..                                              ...
# 486                              Woodlawn (4) Bronx
# 487  World Trade Center / Chambers St (E) Manhattan
# 488           Wyckoff Ave / Myrtle Ave (M) Brooklyn
# 489                            York St (F) Brooklyn
# 490                            Zerega Ave (6) Bronx
#
#                                     LABEL    BOROUGH NGHBHD ROUTES  TRANSFERS  \
# 0                            103rd St (1)  Manhattan   None      1          1
# 1                        103rd St (A,B,C)  Manhattan   None  A,B,C      A,B,C
# 2                            103rd St (6)  Manhattan   None      6          6
# 3             103rd St / Corona Plaza (7)     Queens   None      7          7
# 4                            104th St (A)     Queens   None      A          A
# ..                                    ...        ...    ...    ...        ...
# 486                          Woodlawn (4)      Bronx   None      4          4
# 487  World Trade Center / Chambers St (E)  Manhattan   None      E  A,C,E,2,3
# 488          Wyckoff Ave / Myrtle Ave (M)   Brooklyn   None      M        L,M
# 489                           York St (F)   Brooklyn   None      F          F
# 490                        Zerega Ave (6)      Bronx   None      6          6
#
#            COLOR EXPRESS  CLOSED
# 0            RED    None    <NA>
# 1    BLUE-ORANGE    None    <NA>
# 2          GREEN    None    <NA>
# 3         PURPLE    None    <NA>
# 4           BLUE    None    <NA>
# ..           ...     ...     ...
# 486        GREEN    None    <NA>
# 487         BLUE    None    <NA>
# 488        BROWN    None    <NA>
# 489       ORANGE    None    <NA>
# 490        GREEN    None    <NA>
#
# [491 rows x 14 columns]

# %% [markdown]
# 4.5 Question 5: Unique Values
# Write a SQL query to find the distinct boroughs represented in the nyc_subway_stations dataset.

# %%
# %%sql
# SELECT DISTINCT BOROUGH FROM nyc_subway_stations
# Out:
#          BOROUGH
# 0       Brooklyn
# 1         Queens
# 2      Manhattan
# 3          Bronx
# 4  Staten Island

# %% [markdown]
# 4.6 Question 6: Counting Rows
# Write a SQL query to count the number of subway stations in each borough in the nyc_subway_stations dataset.

# %%
# %%sql
# SELECT BOROUGH, COUNT(*) AS STATION_COUNT
# FROM nyc_subway_stations
# GROUP BY BOROUGH ORDER BY STATION_COUNT DESC
# Out:
#          BOROUGH  STATION_COUNT
# 0       Brooklyn            170
# 1      Manhattan            140
# 2         Queens             90
# 3          Bronx             69
# 4  Staten Island             22

# %% [markdown]
# 4.7 Question 7: Aggregating Data
# Write a SQL query to list the number of subway stations in each borough, sorted in descending order by the count.

# %%
# %%sql
# SELECT BOROUGH, COUNT(*) AS STATION_COUNT
# FROM nyc_subway_stations
# GROUP BY BOROUGH ORDER BY STATION_COUNT DESC
# Out:
#          BOROUGH  STATION_COUNT
# 0       Brooklyn            170
# 1      Manhattan            140
# 2         Queens             90
# 3          Bronx             69
# 4  Staten Island             22

# %% [markdown]
# 4.8 Question 8: Joining Tables
# Write a SQL query to join the nyc_subway_stations and nyc_neighborhoods datasets on the borough name, displaying the subway station name and the neighborhood name.

# %%
# !curl -I 'https://www.google.com/url?q=https%3A%2F%2Fstorage.googleapis.com%2Fqm2%2FCASA0025%2Fnyc_neighborhoods.tsv'
# Out:
# HTTP/2 200
# content-type: text/html; charset=ISO-8859-1
# content-security-policy: object-src 'none';base-uri 'self';script-src 'nonce-PnacvYObfHnEIG_1PYVZWQ' 'strict-dynamic' 'report-sample' 'unsafe-eval' 'unsafe-inline' https: http:;report-uri https://csp.withgoogle.com/csp/gws/other
# reporting-endpoints: default="//www.google.com/httpservice/retry/jserror?ei=WI-Iadj-N7av5NoPgtq9uQM&cad=crash&error=Page%20Crash&jsel=1"
# accept-ch: Sec-CH-Prefers-Color-Scheme
# p3p: CP="This is not a P3P policy! See g.co/p3phelp for more info."
# date: Sun, 08 Feb 2026 13:27:52 GMT
# server: gws
# x-xss-protection: 0
# x-frame-options: SAMEORIGIN
# expires: Sun, 08 Feb 2026 13:27:52 GMT
# cache-control: private
# set-cookie: NID=528=Xwmsw2So37EzsnJlq2kSK4aRFdCUqTolslBwKu4xh07DD2lh2mqyke2w0BBDGE-Lnwo1_dL4ZZ1BnWbeakmQr0vROMe_l6S7WmznMdlj7vt_XEV7_Gmm_4reMw1JIeHXkvKQNtmlejqwBdEnMUJKALYsUkMRU_OrpkIVjAXgj_wnQ30qw-bBwK1xZ5Ea6DQCM-fb407vJqm7fpHCAaqEGoCwUg7luLoPYUs; expires=Mon, 10-Aug-2026 13:27:52 GMT; path=/; domain=.google.com; HttpOnly
# set-cookie: __Secure-BUCKET=CJMF; expires=Fri, 07-Aug-2026 13:27:52 GMT; path=/; domain=.google.com; Secure; HttpOnly

# %%
# %%sql
# CREATE OR REPLACE TABLE nyc_neighborhoods AS
# SELECT *
# FROM read_csv_auto(
#   'https://storage.googleapis.com/qm2/CASA0025/nyc_neighborhoods.tsv',
#   delim='\t',
#   header=true);
# Out:
# Empty DataFrame
# Columns: [Success]
# Index: []

# %%
# %%sql
# SELECT * FROM nyc_neighborhoods
# ORDER BY NAME ASC
# Out:
#           BORONAME                      NAME
# 0    Staten Island                 Annandale
# 1    Staten Island             Ardon Heights
# 2           Queens  Astoria-Long Island City
# 3           Queens                Auburndale
# 4        Manhattan              Battery Park
# ..             ...                       ...
# 124         Queens   Woodhaven-Richmond Hill
# 125      The Bronx         Woodlawn-Nordwood
# 126  Staten Island                   Woodrow
# 127         Queens                  Woodside
# 128      Manhattan                 Yorkville
#
# [129 rows x 2 columns]

# %%
# %%sql
# SELECT
#   s.NAME AS station_name,
#   n.NAME AS neighborhood_name
# FROM nyc_subway_stations AS s
# LEFT JOIN nyc_neighborhoods AS n
#   ON s.BOROUGH = n.BORONAME;
# Out:
#          station_name neighborhood_name
# 0        Cortlandt St         Chinatown
# 1           Rector St         Chinatown
# 2         South Ferry         Chinatown
# 3            W 4th St         Chinatown
# 4             15th St          Red Hook
# ...               ...               ...
# 11122     Tremont Ave              None
# 11123  Westchester Sq              None
# 11124    Whitlock Ave              None
# 11125        Woodlawn              None
# 11126      Zerega Ave              None
#
# [11127 rows x 2 columns]

# %% [markdown]
# 4.9 Question 9: String Manipulation
# Write a SQL query to display the names of subway stations in the nyc_subway_stations dataset that contain the word “St” in their names.

# %%
# %%sql
# SELECT NAME
# FROM nyc_subway_stations
# WHERE NAME LIKE '%St%'
# Out:
#               NAME
# 0     Cortlandt St
# 1        Rector St
# 2         138th St
# 3         149th St
# 4         149th St
# ..             ...
# 225  Beach 98th St
# 226        Main St
# 227    Steinway St
# 228      St George
# 229      Stapleton
#
# [230 rows x 1 columns]

# %% [markdown]
# 4.10 Question 10: Filtering with Multiple Conditions
# Write a SQL query to find all subway stations in the nyc_subway_stations dataset that are in the borough of Brooklyn and have routes that include the letter “R”.

# %%
# %%sql
# SELECT *
# FROM nyc_subway_stations
# WHERE BOROUGH = 'Brooklyn' AND ROUTES LIKE '%R%'
# Out:
#     OBJECTID     ID           NAME                   ALT_NAME       CROSS_ST  \
# 0         81  406.0        25th St                       None        4th Ave
# 1         82  407.0        36th St                       None        4th Ave
# 2         83  408.0        45th St                       None        4th Ave
# 3         86  409.0        53rd St                       None        4th Ave
# 4         88  410.0        59th St                       None        4th Ave
# 5         91  412.0        77th St                       None        4th Ave
# 6         96  413.0        86th St                       None        4th Ave
# 7         98  414.0        95th St                  Bay Ridge        4th Ave
# 8        100  404.0         9th St                    4th Ave        4th Ave
# 9        119  411.0  Bay Ridge Ave                       None        4th Ave
# 10       146  379.0       Court St               Borough Hall    Montague St
# 11       150  382.0     DeKalb Ave                       None   Flatbush Ave
# 12       188  380.0    Lawrence St                  MetroTech  Willoughby St
# 13       213  402.0     Pacific St  Brooklyn Academy of Music        4th Ave
# 14       218  405.0   Prospect Ave                       None        4th Ave
# 15       231  403.0       Union St                       None        4th Ave
#
#                                             LONG_NAME  \
# 0                              25th St (M,R) Brooklyn
# 1                          36th St (D,M,N,R) Brooklyn
# 2                                45th St (R) Brooklyn
# 3                                53rd St (R) Brooklyn
# 4                              59th St (N,R) Brooklyn
# 5                                77th St (R) Brooklyn
# 6                                86th St (R) Brooklyn
# 7                    95th St / Bay Ridge (R) Brooklyn
# 8                     9th St / 4th Ave (M,R) Brooklyn
# 9                          Bay Ridge Ave (R) Brooklyn
# 10             Court St / Borough Hall (M,R) Brooklyn
# 11                      DeKalb Ave (B,M,Q,R) Brooklyn
# 12             Lawrence St / MetroTech (M,R) Brooklyn
# 13  Pacific St / Brooklyn Academy of Music (D,M,N,...
# 14                        Prospect Ave (M,R) Brooklyn
# 15                            Union St (M,R) Brooklyn
#
#                                                LABEL   BOROUGH NGHBHD  \
# 0                                      25th St (M,R)  Brooklyn   None
# 1                                  36th St (D,M,N,R)  Brooklyn   None
# 2                                        45th St (R)  Brooklyn   None
# 3                                        53rd St (R)  Brooklyn   None
# 4                                      59th St (N,R)  Brooklyn   None
# 5                                        77th St (R)  Brooklyn   None
# 6                                        86th St (R)  Brooklyn   None
# 7                            95th St / Bay Ridge (R)  Brooklyn   None
# 8                             9th St / 4th Ave (M,R)  Brooklyn   None
# 9                                  Bay Ridge Ave (R)  Brooklyn   None
# 10                     Court St / Borough Hall (M,R)  Brooklyn   None
# 11                              DeKalb Ave (B,M,Q,R)  Brooklyn   None
# 12                     Lawrence St / MetroTech (M,R)  Brooklyn   None
# 13  Pacific St / Brooklyn Academy of Music (D,M,N,R)  Brooklyn   None
# 14                                Prospect Ave (M,R)  Brooklyn   None
# 15                                    Union St (M,R)  Brooklyn   None
#
#      ROUTES            TRANSFERS                COLOR  EXPRESS  CLOSED
# 0       M,R                  M,R         BROWN-YELLOW     None    <NA>
# 1   D,M,N,R              D,M,N,R  BROWN-ORANGE-YELLOW  express    <NA>
# 2         R                    R               YELLOW     None    <NA>
# 3         R                    R               YELLOW     None    <NA>
# 4       N,R                  N,R               YELLOW  express    <NA>
# 5         R                    R               YELLOW     None    <NA>
# 6         R                    R               YELLOW     None    <NA>
# 7         R                    R               YELLOW     None    <NA>
# 8       M,R                F,M,R         BROWN-YELLOW     None    <NA>
# 9         R                    R               YELLOW     None    <NA>
# 10      M,R          M,R,2,3,4,5         BROWN-YELLOW     None    <NA>
# 11  B,M,Q,R              B,M,Q,R                MULTI  express    <NA>
# 12      M,R                  M,R         BROWN-YELLOW     None    <NA>
# 13  D,M,N,R  B,D,M,N,Q,R,2,3,4,5  BROWN-ORANGE-YELLOW  express    <NA>
# 14      M,R                  M,R         BROWN-YELLOW     None    <NA>
# 15      M,R                  M,R         BROWN-YELLOW     None    <NA>
